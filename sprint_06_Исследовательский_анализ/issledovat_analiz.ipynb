# %% [markdown]
# <div style="border:solid green 2px; padding: 20px">
#
# <b>Евгений, привет!</b> Мы рады тебя видеть на территории код-ревьюеров 😎. Ты проделал большую работу над проектом, но давай познакомимся и сделаем его еще лучше! У нас тут своя атмосфера и несколько правил:
#
#
# 1. Меня зовут Александр Матвеевский. Я работаю код-ревьюером, моя основная цель — не указать на совершенные тобою ошибки, а поделиться своим опытом и помочь тебе стать дата-специалистом.
# 2. Общаемся на ты.
# 3. Если хочешь написать, спросить - не нужно стесняться. Только выбери свой цвет для комментария.
# 4. Это учебный проект, тут можно не бояться сделать ошибку.
# 5. У нас с тобой 6 попыток для сдачи проекта.
# 6. Let's Go!
#
# ---
#
# Я буду красить комментарии цветом, пожалуйста, не удаляй их:
#
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# Такой комментарий нужно исправить обязательно, он критически влияет на удачное выполнение проекта.
# </div>
#
# ---
#
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
#
# Такой комментарий является рекомендацией или советом. Можешь использовать их на своё усмотрение.
# </div>
#
# ---
#
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Такой комментарий  говорит о том, что было сделано что-то качественное и правильное =)
# </div>
#
# ---
#
# Предлагаю работать над проектом в диалоге: если ты что-то меняешь в проекте или отвечаешь на мои комментарии — пиши об этом. Мне будет легче отследить изменения, если ты выделишь свои комментарии:
#
# <div class="alert alert-info"> <b>Комментарии студента:</b> Например, вот так.</div>
#
# Всё это поможет выполнить повторную проверку твоего проекта оперативнее. Если будут какие-нибудь вопросы по моим комментариям, пиши, будем разбираться вместе :)
#
# ---

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
#
# Отличная практика - расписывать цель и основные этапы своими словами (этот навык очень поможет на фильнальном проекте). Хорошо было бы добавить ход и цель исследования. Вот мой личный пример:
#
# ![image.png](attachment:image.png)
#
#
# ---
#
# `PS: из-за этого сообщения может часто возникать ошибка в ноутбуке`. Если мешает, можешь удалить данный комментарий
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №2__
#
#
# Отсутствует вводная часть. Подскажи, пожалуйста, это ошибка при выгрузке или не знаешь, как реализовать вводную часть?

# %% [markdown]
# <div class='alrt alert-info'>Добавил</div>

# %% [markdown]
# ### Оценка стоимости квартир
# Оценка проводится по архиву объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктах за несколько лет. Проводим исследовательский анализ данных и устанавливаем параметры, влияющие на цену объектов.
# 	По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые — получены автоматически на основе картографических данных. Вследствие этого требуется предварительная обработка данных — на предмет пропущенных и аномальных данных.
# Данные: /datasets/real_estate_data.csv
# Скачать датасет
#
# ### Основные этапы работы:
#
# #### Предобработка данных
#     1. Получаем общую картину данных (гистограммы по всем данным) и информацию по количеству и типу данных.
#     2. Изучаем пропущенные значения в столбцах.
#     3. При необходимости корректируем тип данных .
#     4. Изучаем названия населённых пунктов и корректируем в случае необходимости.
# #### Добавляем в таблицу новые столбцы со следующими параметрами
#     • цена одного квадратного метра (нужно поделить стоимость объекта на его общую площадь, а затем округлить до двух знаков после запятой);
#     • день недели публикации объявления (0 — понедельник, 1 — вторник и так далее);
#     • месяц публикации объявления;
#     • год публикации объявления;
#     • тип этажа квартиры (значения — «‎первый», «последний», «другой»);
#     • расстояние до центра города в километрах (переведите из м в км и округлите до ближайших целых значений).
# #### Проводим исследовательский анализ данных:
# - Корректируем аномальные данные
# - Строим зависимости стоимости от следующих параметров:
#         ◦ общая площадь;
#         ◦ жилая площадь;
#         ◦ площадь кухни;
#         ◦ цена объекта;
#         ◦ количество комнат;
#         ◦ высота потолков;
#         ◦ тип этажа квартиры («первый», «последний», «другой»);
#         ◦ общее количество этажей в доме;
#         ◦ расстояние до центра города в метрах;
#         ◦ расстояние до ближайшего парк
# - Изучаем, как быстро продавались квартиры.
# - Считаем среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений
# - Рассчитаем среднюю стоимость квадратного метра квартир в зависимости от расстояния до центра города.
# #### Описание данных
#     • airports_nearest — расстояние до ближайшего аэропорта в метрах (м)
#     • balcony — число балконов
#     • ceiling_height — высота потолков (м)
#     • cityCenters_nearest — расстояние до центра города (м)
#     • days_exposition — сколько дней было размещено объявление (от публикации до снятия)
#     • first_day_exposition — дата публикации
#     • floor — этаж
#     • floors_total — всего этажей в доме
#     • is_apartment — апартаменты (булев тип)
#     • kitchen_area — площадь кухни в квадратных метрах (м²)
#     • last_price — цена на момент снятия с публикации
#     • living_area — жилая площадь в квадратных метрах (м²)
#     • locality_name — название населённого пункта
#     • open_plan — свободная планировка (булев тип)
#     • parks_around3000 — число парков в радиусе 3 км
#     • parks_nearest — расстояние до ближайшего парка (м)
#     • ponds_around3000 — число водоёмов в радиусе 3 км
#     • ponds_nearest — расстояние до ближайшего водоёма (м)
#     • rooms — число комнат
#     • studio — квартира-студия (булев тип)
#     • total_area — общая площадь квартиры в квадратных метрах (м²)
#     • total_images — число фотографий квартиры в объявлении

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №3__
#
# Супер, старайся, пожалуйста, придерживаться этой стратегии в дальнейших проектах =)
# </div>

# %% [markdown]
# ### Предварительные действия

# %%
# Импортируем библиотеки.
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Получаем данные, выводим общие сведения о данных.
data = pd.read_csv('/datasets/real_estate_data.csv', sep='\t')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %% [markdown]
# Из представленных данных видно, в основном они типа float64. Общее количество записей 23698, в некоторых записях присутствуют не все данные, то есть необходимо обработать пропущенные значения.

# %%
# Строим набор диаграмм для предварительного изучения.
data.hist(figsize=(15, 20))
data_temp = data  # сохраним на всякий случай
plt.show()

# %% [markdown]
# Большинство гистограмм показывают наибольшее количество записей при малых значениях целевых данных, т. е. имеется явная зависимость. Однако наблюдаются и резкие "выбросы", что необходимо исследовать отдельно.

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# Предлагаю разделять логически разные вещи:
#
#     - импорты библиотек
#     - открытие данных (это может быть не тривиальный процесс)
#     - рабочий код
#
# Такой подход позволит улучшить читаемость кода, снизит время поиска ошибок если они есть и исключит повторное выполнение кода

# %% [markdown]
# <div class="alert alert-info">
#   Разделил на 3 части, добавил краткий анализ полученных данных и построенных диаграмм. Прокомментировал полученные результаты.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Супер, старайся, пожалуйста, придерживаться этой стратегии в дальнейших проектах =)
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# Хорошо бы как нибудь прокомментировать полученные данные в разделе
# </div>

# %% [markdown]
# ###  Выполняем предобработку данных
# #### Замена пропущенных значений и замена типа данных
#
# Количественные параметры квартир
#
# - Отсутствующие балконы = 0  у некоторых квартир нет балконов.
#
# - Отсутствующие указания количества этажей = 1  в одноэтажном доме нет смысла, так же как и для частного дома где все этажи есть.
#
# - Отсутствующий этаж = 1 , один точно есть, в частном доме есть все этажи.

# %%
# Балконы - замена на 0 и приведение к целому
data['balcony'] = pd.to_numeric(data['balcony']).fillna(0)
data['balcony'] = data['balcony'].astype(int)
# Этажность
data['floors_total'] = pd.to_numeric(data['floors_total']).fillna(1)

# Этаж с приведением к целому типу

data['floor_changeed'] = pd.to_numeric(data['floor']).fillna(1)

# %%
# Замена отсутствующих данных по количеству комнат = 1

data['rooms'] = pd.to_numeric(data['rooms']).fillna(1)

# %%
# Вывод обновлённой информации

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23699 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               23699 non-null  int64
#  14  locality_name         23650 non-null  object
# ...

# %% [markdown]
# Пропуски с заменой типа данных
#
# - Аппартаменты или нет - в логический тип, пропущенные = 0  "да" или "нет", гораздо чаще "нет"
#
# - Дней с выставления - в целый тип, пропущенные = 1  если объявление есть - 1 день точно
#
# - Наличие аэропортов, центров, парков и прудов = 0   нет такого вблизи

# %%
# Аппартаменты
data['is_apartment'] = data['is_apartment'].astype('bool').fillna(0)

# Дней с выставления
data['days_exposition'] = pd.to_numeric(data['days_exposition']).fillna(1)

# Количество ближайших...
to_zero_nearests = ['airports_nearest', 'cityCenters_nearest', 'parks_around3000', 'parks_nearest', 'ponds_around3000', 'ponds_nearest']
for param in (to_zero_nearests):
    data[param] = data[param].fillna(0)

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23699 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          23699 non-null  bool
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               23699 non-null  int64
#  14  locality_name         23650 non-null  object
# ...

# %% [markdown]
# Пропущенные значения остаются в высоте потолков, жилой площади, площади кухни.

# %%
# Просмотр высоты потолков по убыванию
print(data.sort_values(by='ceiling_height', ascending=False)['ceiling_height'].head(30))
# Out:
# 22869    100.0
# 22336     32.0
# 3148      32.0
# 21377     27.5
# 20478     27.0
# 5246      27.0
# 5807      27.0
# 10773     27.0
# 17857     27.0
# 22938     27.0
# 21824     27.0
# 4876      27.0
# 5669      26.0
# 18545     25.0
# 11285     25.0
# 355       25.0
# 6246      25.0
# 14382     25.0
# 4643      25.0
# 9379      25.0
# 5076      24.0
# 20507     22.6
# 17496     20.0
# 15061     14.0
# 22309     10.3
# 5863       8.3
# 15743      8.0
# 3474       8.0
# 17442      8.0
# 20264      6.0
# Name: ceiling_height, dtype: float64

# %% [markdown]
# https://www.cian.ru/stati-vysokie-potolki-za-i-protiv-312614/#:~:text=%D0%90%20%D0%B2%D0%BE%D1%82%20%D0%BC%D0%B8%D0%BD%D0%B8%D0%BC%D0%B0%D0%BB%D1%8C%D0%BD%D1%8B%D0%B5%20%D0%B7%D0%BD%D0%B0%D1%87%D0%B5%D0%BD%D0%B8%D1%8F%20%D0%B2%D1%81%D0%B5,%D0%BD%D0%B5%20%D0%BD%D0%B8%D0%B6%D0%B5%202%2C7%20%D0%BC.
#     Минимальная высота потолков 2,5 м, максимальная не определена. Логично предположить что неправильно поставлена десятичная запятая. Заменяем значения большие 25 м на x / 10 м.

# %%
data['ceiling_height_modified'] = data['ceiling_height'].apply(lambda x: x / 10 if x >= 25 else x)
# Просмотр высоты потолков по убыванию
print(data.sort_values(by='ceiling_height_modified', ascending=False)['ceiling_height_modified'].head(30))
# Out:
# 5076     24.00
# 20507    22.60
# 17496    20.00
# 15061    14.00
# 22309    10.30
# 22869    10.00
# 5863      8.30
# 17442     8.00
# 15743     8.00
# 3474      8.00
# 20264     6.00
# 21227     5.80
# 1388      5.60
# 7578      5.50
# 12628     5.30
# 1026      5.30
# 464       5.20
# 1053      5.00
# 21923     4.90
# 2802      4.80
# 1300      4.70
# 19142     4.70
# 12401     4.65
# 6802      4.50
# 3067      4.50
# 10159     4.50
# 13224     4.50
# 14519     4.50
# 9783      4.50
# 2823      4.50
# Name: ceiling_height_modified, dtype: float64

# %%
# В продолжение работы с потолками - заменяю неуказанные высоты на медианное значение потолков в изменённом столбце - на месте.
# и проверяю хвост данных.
# ceiling_height_median = data['ceiling_height_modified'].median()
# print('median - > ', ceiling_height_median, 'm')
# data['ceiling_height_modified'] = data['ceiling_height_modified'].fillna(ceiling_height_median)
# data['ceiling_height_modified'] = data['ceiling_height_modified'].apply(lambda x: ceiling_height_median if x < 2.5 else x)
# print(data.sort_values(by='ceiling_height_modified', ascending=False)['ceiling_height_modified'].tail(20))
# Пропусков нет

# %%
# median_living_area = data['living_area'].median()
# median_kitchen_area = data['kitchen_area'].median()
# data['living_area'] = data['living_area'].fillna(median_living_area)
# data['kitchen_area'] = data['kitchen_area'].fillna(median_kitchen_area)

# %% [markdown]
# <div class='alert alert-info'>Перенёс действия ниже - после очистки названий пунктов</div>

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# А какой смысл замены на рандомную медиану/среднее/моду/0/-1 и т.д.? Не стоит заполнять пропуски просто так, это плохая практика. Замена пропусков всегда должна быть корректна и обоснована. Например, если продавец не указал число балконов, то, скорее всего, в его квартире их нет. Такие пропуски правильно заменить на 0
#
# В остальных случаях, просто смещаешь реальное распределение данных
# </div>

# %% [markdown]
# <div class="alert alert-info">
#     <li>Разделил замену явно пропущенных значений и замену с обработкой. В первой части с приведением к другому типу. Снова проверил пропущенные
#     <li>Пересмотрел замену высоты потолков - по рекомендации - уменьшил - учтя минимально допустимые высоты</li>
#     <li>В хвосте обнаружились высоты порядка 1 м - их тоже заменил на медиану</li>
#     <li>Повторил замену по площадям</li>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №2__
#
# Замена пропущенных значений на медиану/среднее/моду и т.д. может исказить данные и внести некоторую проблему при дальнейшем анализе.
#
# Когда мы заменяем пропущенные значения на медиану, мы фактически добавляем новые значения в набор данных. Это может привести к смещению распределения и искажению статистических свойств данных. Замена на медиану может привести к тому, что данные будут выглядеть более однородными, чем они есть на самом деле.
#
# Возможные последствия: Замена пропущенных значений на медиану может повлиять на многие аспекты анализа данных:
#
#    - Статистические тесты: Искаженные данные могут привести к неправильным выводам в статистических тестах. Использование искаженных данных может привести к неверным результатам тестов на значимость и оценке эффектов между группами или условиями.
#
#    - Моделирование: В случае использования искаженных данных для построения моделей, модели также могут страдать от искажения и давать неправильные предсказания или выводы. Это может быть особенно важно, если пропущенные значения связаны с ключевыми переменными модели.
#
#    - Выводы и интерпретация: Искаженные данные могут привести к неверным выводам и неправильной интерпретации результатов. Например, если пропущенные значения связаны с важными факторами, замена на медиану может привести к неправильному пониманию влияния этих факторов на исследуемую переменную.
#
#
# ---
#
# Если ничем логичным не заменить, то правильнее оставить эти пропуски

# %% [markdown]
# <div class="alert alert-info">Убрал замену пропущенных значений</div>

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №3__
#
# В 11 ячейке меняешь пропуски на обычную медиану
#
# ![image.png](attachment:image.png)

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №4__
#
# Здорово, что разобрались

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №3__
#
# Некоторые столбцы можно поменять на значения, относительно своего района (например высота пололков). Вот так
#
#
# ![image.png](attachment:image.png)
#
# Если хочешь - дарю свой код =)
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Некоторые столбцы можно поменять на значения, относительно своего района (например высота пололков). Вот так
#
#
# ![image.png](attachment:image.png)
#
# Если хочешь - дарю свой код =)
# </div>
#
#
#
#
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# #### Обрабатываем некорректные названия

# %%
def clean_locality(place):
    if isinstance(place, str) and place != '':
        return place.split()[-1]  # Берем последнее слово
    return "None"  # Возвращаем NaN для нестроковых или пустых значений

data['clean_locality_name'] = data['locality_name'].apply(clean_locality)
print(data['clean_locality_name'].head(20))
# Out:
# 0     Санкт-Петербург
# 1              Шушары
# 2     Санкт-Петербург
# 3     Санкт-Петербург
# 4     Санкт-Петербург
# 5             Янино-1
# 6           Парголово
# 7     Санкт-Петербург
# 8              Мурино
# 9     Санкт-Петербург
# 10    Санкт-Петербург
# 11          Ломоносов
# 12          Сертолово
# 13           Петергоф
# 14             Пушкин
# 15    Санкт-Петербург
# 16    Санкт-Петербург
# 17    Санкт-Петербург
# 18    Санкт-Петербург
# 19    Санкт-Петербург
# Name: clean_locality_name, dtype: object

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Можно например вот так:
#
#     df = df.apply(lambda x: x.replace({'поселок':'посёлок', 'городской посёлок': 'посёлок', 'посёлок городского типа': 'посёлок', 'коттеджный посёлок': 'посёлок', 'посёлок при железнодорожной станции': 'посёлок станции'}, regex=True))
#
#     len(df.locality_name.unique())
#
# </div>

# %%
# Замена пропущенных значений по площадям жилой и кухни - по медианным значениям локального расположения
for locality_name in data['clean_locality_name'].unique():
    median = data.loc[data['clean_locality_name'] == locality_name, 'living_area'].median()
    if median:
        data.loc[(data['living_area'].isna()) & (data['clean_locality_name'] == locality_name), 'living_area'] = median
    
for locality_name in data['clean_locality_name'].unique():
    median = data.loc[data['clean_locality_name'] == locality_name, 'kitchen_area'].median()
    if median:
        data.loc[(data['kitchen_area'].isna()) & (data['clean_locality_name'] == locality_name), 'kitchen_area'] = median
# # -- 
print('уникальных', len(data['clean_locality_name'].unique()))
data.info()
# Out:
# уникальных 295
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   total_images             23699 non-null  int64
#  1   last_price               23699 non-null  float64
#  2   total_area               23699 non-null  float64
#  3   first_day_exposition     23699 non-null  object
#  4   rooms                    23699 non-null  int64
#  5   ceiling_height           14504 non-null  float64
#  6   floors_total             23699 non-null  float64
#  7   living_area              23699 non-null  float64
#  8   floor                    23699 non-null  int64
#  9   is_apartment             23699 non-null  bool
#  10  studio                   23699 non-null  bool
#  11  open_plan                23699 non-null  bool
#  12  kitchen_area             23699 non-null  float64
# ...

# %% [markdown]
# <div class='alert alert-info'>Скорректировал<br>Пропусков не наблюдается<br>за пример кода спасибо) была похожая мысль, но не знал как реализовать..<br> Не нашёл как связаться по вопросу кода.. всё время выходила ошибка по пустому срезу..<br>Всего найдено 295 уникальных пунктов, из них 17 полностью заполнены Nan - выходила ошибка, сделал замену по условию что медиана существует. Со значениями NaN должны остаться 17 пунктов.</div>

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# Не все столбцы имеют корректный тип данных. Например `balcony` имеет дробный тип. Но ведь не может быть 1.5 балкона в доме. Как думаешь?
# </div>

# %% [markdown]
# <div class='alert alert-info'>Балконы поправил сразу после вставки 0</div>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 25 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   total_images             23699 non-null  int64
#  1   last_price               23699 non-null  float64
#  2   total_area               23699 non-null  float64
#  3   first_day_exposition     23699 non-null  object
#  4   rooms                    23699 non-null  int64
#  5   ceiling_height           14504 non-null  float64
#  6   floors_total             23699 non-null  float64
#  7   living_area              21796 non-null  float64
#  8   floor                    23699 non-null  int64
#  9   is_apartment             23699 non-null  bool
#  10  studio                   23699 non-null  bool
#  11  open_plan                23699 non-null  bool
#  12  kitchen_area             23681 non-null  float64
#  13  balcony                  23699 non-null  int64
# ...

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Столбцы имеют корректный тип данных

# %%
duplicates = data.duplicated()
print(data[duplicates])
# Out:
# Empty DataFrame
# Columns: [total_images, last_price, total_area, first_day_exposition, rooms, ceiling_height, floors_total, living_area, floor, is_apartment, studio, open_plan, kitchen_area, balcony, locality_name, airports_nearest, cityCenters_nearest, parks_around3000, parks_nearest, ponds_around3000, ponds_nearest, days_exposition, floor_changeed, ceiling_height_modified, clean_locality_name]
# Index: []
#
# [0 rows x 25 columns]

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №2__
#
# Можно проще:
#
#     df.duplicated().sum()

# %% [markdown]
# <div class='alert alert-info'>Вот тут совсем не понял что требуется..</div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Какой именно пункт вызвал затруднения?

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# Отсутствует проверка на явные дубликаты, поправишь, пожалуйста?
#
# ---
#
# Так же отсутствует вывод после раздела (можно описать качество исходных данных). Поправишь, этот момент в проекте?
# </div>

# %% [markdown]
# <div class="alert alert-info">Вывод по предобработке добавил выше. Вижу что дубликатов не наблюдается.</div>

# %% [markdown]
# #### Выводы по предобработке
# Предоставленные данные были обработаны, были проведены:
#
# - замена пропущенных значений (на наиболее вероятные, среднестатистические)
#
# - замена ошибочно введённых данных
#
# - замена названий на более пригодные для обработки
#
# Рекомендация - проводить предварительные проверки введённых данных непосредственно в процессе ввода

# %% [markdown]
# ### 3 Добавляем новые столбцы

# %%
# Цена 1 кв метра
data['price_per_sqm'] = round(data['last_price'] / data['total_area'], 2)

# %%
# День недели публикации - week_day_pub, месяц - month, год - year_pub
data['week_day_pub'] = pd.to_datetime(data['first_day_exposition']).dt.weekday

data['month_pub'] = pd.to_datetime(data['first_day_exposition']).dt.month

data['year_pub'] = pd.to_datetime(data['first_day_exposition']).dt.year

# %%
# Тип этажа квартиры: floor_type -> 1-й, последний, другой.

def floor_type(row):
    if row['floor'] == 1:
        return 'первый'
    elif row['floor'] == row['floors_total']:
        return 'последний'
    else:
        return 'другой'
    
data['floor_type'] = data.apply(floor_type, axis=1)
print(data['floor_type'])
# Out:
# 0        другой
# 1        первый
# 2        другой
# 3        другой
# 4        другой
#           ...
# 23694    другой
# 23695    другой
# 23696    первый
# 23697    другой
# 23698    первый
# Name: floor_type, Length: 23699, dtype: object

# %%
# Расстояние до центра города - distance_to_center

data['distance_to_center'] = round(data['cityCenters_nearest'] / 1000)

# %%
# Вывод полученного результата

data.head(15)
# Out:
#     total_images  last_price  total_area first_day_exposition  rooms  \
# 0             20  13000000.0      108.00  2019-03-07T00:00:00      3
# 1              7   3350000.0       40.40  2018-12-04T00:00:00      1
# 2             10   5196000.0       56.00  2015-08-20T00:00:00      2
# 3              0  64900000.0      159.00  2015-07-24T00:00:00      3
# 4              2  10000000.0      100.00  2018-06-19T00:00:00      2
# 5             10   2890000.0       30.40  2018-09-10T00:00:00      1
# 6              6   3700000.0       37.30  2017-11-02T00:00:00      1
# 7              5   7915000.0       71.60  2019-04-18T00:00:00      2
# 8             20   2900000.0       33.16  2018-05-23T00:00:00      1
# 9             18   5400000.0       61.00  2017-02-26T00:00:00      3
# 10             5   5050000.0       39.60  2017-11-16T00:00:00      1
# 11             9   3300000.0       44.00  2018-08-27T00:00:00      2
# 12            10   3890000.0       54.00  2016-06-30T00:00:00      2
# ...

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# Не стоит писать весь код в одной ячейке. Это плохая практика (поскольку его тяжело читать). Лучше так: одна ячейка = одна логика

# %% [markdown]
# <div class='alert alert-info'>Исправил</div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Да, так корректно

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Совет на будущие работы `(в этом проекте этот метод не нужен)`: обычно в датафреймах содержатся данные за несколько лет. Важно выбрать корректный метод для вычленения месяца, иначе месяца разных годов могут стать одним месяцем. Обрати внимание на метод astype('datetime64[M]'). Для его использования не нужно обращаться к pd.DatetimeIndex.
#
# Вот хорошая статья на этот счёт:
#
#      https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.astype.html
#
#     и
#
#     https://www.sharpsightlabs.com/blog/pandas-astype/
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# Хорошо бы проверить функцию, вывев уникальные значения нового столбца

# %% [markdown]
# <div class='alert alert-info'>Не понял. Какого именно столбца? </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №2__
#
# Выше ты добавил новый столбец в свой датасет с помощью функции. Хорошо бы проверь функцию на корректность

# %% [markdown]
# <div class="alert alert-info">Вывел столбец с типом этажа: видны "первый", "другой"...</div>

# %% [markdown]
# ### 4 Исследовательский анализ данных.

# %%
# Построение гистограм

fig, axes = plt.subplots(1, 3, figsize=(15, 5))
axes[0].hist(data['total_area'], bins=100, range=(0, 200))
axes[1].hist(data['living_area'], bins=100, range=(0, 100))
axes[2].hist(data['kitchen_area'], bins=100, range=(0, 50))
# Out:
# (array([0.000e+00, 0.000e+00, 1.000e+00, 0.000e+00, 9.000e+00, 1.000e+00,
#         1.000e+01, 8.000e+00, 3.400e+01, 4.200e+01, 8.350e+02, 7.800e+02,
#         2.177e+03, 6.620e+02, 1.647e+03, 6.080e+02, 2.183e+03, 9.920e+02,
#         1.595e+03, 1.961e+03, 2.137e+03, 8.710e+02, 1.206e+03, 4.080e+02,
#         9.320e+02, 3.180e+02, 5.480e+02, 2.450e+02, 5.320e+02, 1.920e+02,
#         4.830e+02, 1.280e+02, 2.610e+02, 1.000e+02, 1.820e+02, 7.800e+01,
#         1.470e+02, 5.500e+01, 1.110e+02, 4.300e+01, 1.530e+02, 3.500e+01,
#         6.500e+01, 3.600e+01, 8.200e+01, 2.400e+01, 6.600e+01, 2.300e+01,
#         4.400e+01, 1.600e+01, 7.700e+01, 7.000e+00, 3.600e+01, 9.000e+00,
#         2.200e+01, 9.000e+00, 3.500e+01, 9.000e+00, 1.900e+01, 9.000e+00,
#         6.300e+01, 7.000e+00, 1.400e+01, 7.000e+00, 1.700e+01, 5.000e+00,
#         1.000e+01, 4.000e+00, 9.000e+00, 6.000e+00, 2.900e+01, 6.000e+00,
#         1.800e+01, 2.000e+00, 5.000e+00, 8.000e+00, 7.000e+00, 1.000e+00,
# ...

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
#
# На такой визуализации плохо видно распределение данных. Чем проще график, тем лучше. Давай их разделим на отдельные 3 чарта

# %% [markdown]
# <div class='alert alert-info'>Не сообразил как убрать лишний вывод. Искал как вывести на одну строку..</div>

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №2__
#
# Я бы советовал сократить range и тогда мы сможем увидеть пиковые значения.
# </div>

# %% [markdown]
# <div class="alert alert-info">Пик сответветствует примерно одному типу квартир - 30-35 м<sup>2</sup>. Это гостинки - самые дешевые, но и продаются они чаще, много студентов ит пр.</div>

# %% [markdown]
# Наблюдаемая зависимость - максимальное количнство продаваемых квартир - с малой площадью (меньше стоимость).

# %%
# Построение диграмм. Набор 2 Этажность.

data['floors_total'].hist(bins=100, range=(0, 2))
data['floor_type'].hist(bins=100)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Вывод - лучше продаются не крайние этажи.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Полученные данные соответствуют реалиям
# </div>

# %%
data['rooms'].hist(bins=100, range=(1, 10))
# Out:
# <AxesSubplot:>

# %% [markdown]
# Маскимальные продажи - 1 и 2-х комнатные - согласуется с зависимостью по площади.

# %%
data['ceiling_height'].hist(bins=100, range=(2, 5))
# Out:
# <AxesSubplot:>

# %% [markdown]
# Пик по высоте в районе 2,5 метров - максимальное количество квартир одного типа (хрущёвки - 2,5 м)

# %%
data['last_price'].hist(bins=100, range=(0, 0.5e8))
# Out:
# <AxesSubplot:>

# %% [markdown]
# Самые частые объявления (самые популярные) в районе 5 млн. руб.

# %%
data['cityCenters_nearest'].hist(bins=100)
data['parks_nearest'].hist(bins=100)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Резкий пик - квартиры в крупных городах - максимальное количество объявлений: радиус примерно 6 км - размер города. Большие расстояния - пригороды, посёлки.

# %%
data['ceiling_height_modified'].unique()
# Out:
# array([ 2.7 ,   nan,  3.03,  2.5 ,  2.67,  2.56,  3.05,  2.75,  2.6 ,
#         2.9 ,  2.8 ,  2.55,  3.  ,  2.65,  3.2 ,  2.61,  3.25,  3.45,
#         2.77,  2.85,  2.64,  2.57,  4.15,  3.5 ,  3.3 ,  2.71,  4.  ,
#         2.47,  2.73,  2.84,  3.1 ,  2.34,  3.4 ,  3.06,  2.72,  2.54,
#         2.51,  2.78,  2.76,  2.58,  3.7 ,  2.52,  5.2 ,  2.87,  2.66,
#         2.59,  2.  ,  2.45,  3.6 ,  2.92,  3.11,  3.13,  3.8 ,  3.15,
#         3.55,  3.16,  3.62,  3.12,  2.53,  2.74,  2.96,  2.46,  5.3 ,
#         5.  ,  2.79,  2.95,  4.06,  2.94,  3.82,  3.54,  3.53,  2.83,
#         4.7 ,  2.4 ,  3.38,  3.01,  5.6 ,  3.65,  3.9 ,  3.18,  3.35,
#         2.3 ,  3.57,  2.48,  2.62,  2.82,  3.98,  2.63,  3.83,  3.52,
#         3.95,  3.75,  2.88,  3.67,  3.87,  3.66,  3.85,  3.86,  4.19,
#         3.24,  4.8 ,  4.5 ,  4.2 ,  3.36,  3.08,  3.68,  3.07,  3.37,
#         3.09,  8.  ,  3.26,  3.34,  2.81,  3.44,  2.97,  3.14,  4.37,
# ...

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# Давай рассмотрим аномалии в высоте потолков? Наблюдаем значения в 20, 22...100 метров. Вероятнее всего пользователь забыл поставить разделяющий знак. Поправь, этот момент, пожалуйста
# </div>

# %% [markdown]
# <div class="alert alert-info">Поправил</div>

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №2__
#
# Если честно, то не увидел корректировки. Подскажи, пожалуйста, в какой ячейке она реализована?
#
# ![image.png](attachment:image.png)

# %% [markdown]
# <div class="alert alert-info">В 14-й. Забыл изменить название в выводе - 'ceil_height_modified'</div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №3__
#
# Всё правильно

# %%
# Как быстро продавались квартиры

print(data['days_exposition'].describe())
# Out:
# count    23699.000000
# mean       156.743069
# std        213.448682
# min          1.000000
# 25%         22.000000
# 50%         74.000000
# 75%        199.000000
# max       1580.000000
# Name: days_exposition, dtype: float64

# %% [markdown]
# Из анализа данных: быстрыми можно считать сроки в первом квартиле(?)  - быстрее 22 дней, долгими - в последнем, т. е. дольше 199 дней. В среднем - 156 дней.

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# Немного не так, чтобы ответить на вопрос "Какие продажи можно считать быстрыми, а какие — необычно долгими?" лучше посмотреть на распределение данных с помощью boxplot() или describe().
# </div>

# %% [markdown]
# <div class='alert alert-info'>поправил</div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Тут согласен

# %% [markdown]
# #### Факторы, влияющие на стоимость.

# %%
data.plot(x='total_area', y='last_price', kind='scatter', title='График зависимости цены от общей площади')
plt.xlabel('total_area')
plt.ylabel('last_price')
plt.show()
# Вычисляем и выводим коэффициент Пирсона
k_Pirs = data['last_price'].corr(data['total_area'])
print('Коэффициент Пирсона', round(k_Pirs, 3))
# Out:
# Коэффициент Пирсона 0.654

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Здорово, что зависимость нелинейных данных рассматриваешь через тип графика scatter
# </div>

# %% [markdown]
# С увеличение площади стоимость растёт. Максимальное количество объявлений для квартир с меньшей площадью. В целом наблюдается линейная зависимость. Коэффициент Пирсона подтверждает возможную связь.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Верная интерпретация значений корреляции Пирсона. Ты молодец =)
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
#
# Давай графики зависимостей нелинейных данных (площади) подкрепим корреляцией Пирсона и сразу интерпретировать полученные данные в разделе?
# </div>

# %% [markdown]
# <div class='alert alert-info'>Поправил, добавил коэффициент корреляции</div>

# %%
# Для сглаживания применён метод скользящего среднего.
data['smoothed_living_area'] = data['living_area'].rolling(window=3, min_periods=1).mean()
data.plot(x='smoothed_living_area', y='last_price', kind='scatter', title='График зависимости цены от жилой площади')
plt.xlabel('living_area')
plt.ylabel('last_price')
plt.show()
# Вычисляем и выводим коэффициент Пирсона
k_Pirs = data['last_price'].corr(data['living_area'])
print('Коэффициент Пирсона', round(k_Pirs, 3))
# Out:
# Коэффициент Пирсона 0.566

# %% [markdown]
# Зависимость та же, коэффициент корреляции подтверждает возможную связь.

# %%
# Для сглаживания применён метод скользящего среднего.
data['smoothed_kitchen_area'] = data['living_area'].rolling(window=3, min_periods=1).mean()
data.plot(x='smoothed_kitchen_area', y='last_price', kind='scatter', title='График зависимости цены от площади кухни')
plt.xlabel('kitchen_area')
plt.ylabel('last_price')
plt.show()
# Вычисляем и выводим коэффициент Пирсона
k_Pirs = data['last_price'].corr(data['kitchen_area'])
print('Коэффициент Пирсона', round(k_Pirs, 3))
# Out:
# Коэффициент Пирсона 0.443

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
#
# Некорректная подпись оси абсцисс (тут не общая площадь, а кухни). Поправь, пожалуйста, оформление графиков по всему проекту самостоятельно

# %% [markdown]
# <div class='alert alert-info'>Поправил</div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Учтено

# %% [markdown]
# Та же зависимость, но скорость роста меньше, о чём говорит и меньший коэффициент Пирсона
# <div class='alert alert-info'>Ввёл поправку с учётом коэффициента</div>

# %%
# Зависимость от количества комнат

grouped = data.groupby('rooms')['last_price'].mean().reset_index()
# print(grouped['rooms']).isna().sum()
grouped.plot(x='rooms', y='last_price', kind='bar', title='График зависимости цены от количества комнат')
plt.xlabel('rooms')
plt.ylabel('last_price')
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# Зависимости дискретных данных (тип этажа, месяц, комнаты) лучше рассмотреть на линейной или столбчатой диаграмме (сгруппировав предварительно)
# </div>

# %% [markdown]
# Наиболее популярные квартиры - 5 - 8 комнатные. Очень странный выброс для 12-ти комнатных.
# <div class='alert alert-info'>Вообще нет идей как здесь что-то интерпретировать..</div>

# %%
data.plot(x='floor_type', y='last_price', kind='scatter', title='График зависимости цены от типа этажа')
plt.xlabel('floor_type')
plt.ylabel('last_price')
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# По заданию нужно рассмотреть тип этажа, а не этажность

# %% [markdown]
# <div class='alert alert-info'>Поправил</div>

# %% [markdown]
# Наименьший спрос на квартиры на 1-м этаже. Высокий спрос на последние этажи можно объяснить более низкой ценой.

# %%
# Группируем по днямт недели, месяцам, годам

grouped_days = data.groupby('week_day_pub')['last_price'].mean().reset_index()
grouped_months = data.groupby('month_pub')['last_price'].mean().reset_index()
grouped_year = data.groupby('year_pub')['last_price'].mean().reset_index()

# %%
# Зависимости от дня, месяца и года 


plt.figure(figsize=(15, 5))
plt.subplot(1, 3, 1)
plt.bar(grouped_days['week_day_pub'], grouped_days['last_price'])
plt.title('Зависимость от дня недели')
plt.xlabel('День')
plt.ylabel('Цена')

plt.subplot(1, 3, 2)
plt.bar(grouped_months['month_pub'], grouped_months['last_price'])
plt.title('Зависимость от месяца')
plt.xlabel('Месяц')
plt.ylabel('Цена')

plt.subplot(1, 3, 3)
plt.bar(grouped_year['year_pub'], grouped_year['last_price'])
plt.title('Зависимость от года')
plt.xlabel('Год')
plt.ylabel('Цена')

plt.tight_layout()
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
#
# Не совсем, по заданию нужно рассмотреть раздельно день, месяц, год. Поправь, пожалуйста

# %% [markdown]
# <div class='alrt alert-info'>Поправил</div>

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №2__
#
#
# А что видно на таких графиках? Зависимости дискретных данных (тип этажа, месяц, комнаты) лучше рассмотреть на линейной или столбчатой диаграмме (`сгруппировав` предварительно)

# %% [markdown]
# <div class='alrt alert-info'>Поправил тип графиков и предварительную группировку.</div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №3__
#
# Учтено

# %% [markdown]
# Не наблюдается закономерностей.

# %% [markdown]
# #### 4. Средняя стоимость квадратного метра по населённым пунктам.

# %%
# Группируем по населённым пунктам
grouped = data.groupby('clean_locality_name').agg(
    num_ads=('clean_locality_name', 'size'),  # Количество объявлений
    avg_price_per_sqm=('price_per_sqm', 'median')  # Средняя цена за квадратный метр
).reset_index()

# Сортируем по количеству объявлений и выбираем топ-10
top_10_localities = grouped.sort_values(by='num_ads', ascending=False).head(10)

# Выделяем населённые пункты с самой высокой и низкой стоимостью квадратного метра
max_price_locality = top_10_localities.loc[top_10_localities['avg_price_per_sqm'].idxmax()]
min_price_locality = top_10_localities.loc[top_10_localities['avg_price_per_sqm'].idxmin()]

# Выводим результаты
print("Топ-10 населённых пунктов по количеству объявлений:")
print(top_10_localities)

print("\nНаселённый пункт с самой высокой стоимостью квадратного метра:")
print(max_price_locality)

print("\nНаселённый пункт с самой низкой стоимостью квадратного метра:")
print(min_price_locality)
# Out:
# Топ-10 населённых пунктов по количеству объявлений:
#     clean_locality_name  num_ads  avg_price_per_sqm
# 216     Санкт-Петербург    15721         104761.900
# 139              Мурино      590          86175.640
# 103             Кудрово      472          95675.475
# 287              Шушары      440          76876.175
# 29           Всеволожск      398          65789.470
# 193              Пушкин      369         100000.000
# 89              Колпино      338          74723.745
# 158           Парголово      327          91642.860
# 37              Гатчина      307          67796.610
# 30               Выборг      237          58158.320
#
# Населённый пункт с самой высокой стоимостью квадратного метра:
# clean_locality_name    Санкт-Петербург
# num_ads                          15721
# avg_price_per_sqm             104761.9
# Name: 216, dtype: object
#
# Населённый пункт с самой низкой стоимостью квадратного метра:
# clean_locality_name      Выборг
# num_ads                     237
# ...

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# Таблица верна. Совет: на общие продажи лучше смотреть через призму медианы. Она более устойчива к выбросам
# </div>

# %% [markdown]
# <div class='alert alert-info'>медиану поставил</div>

# %% [markdown]
# #### 5. Зависимость стоимости от расстояния до центра

# %%
data_Spb = data[data['clean_locality_name'] == 'Санкт-Петербург']
# data_Spb.head()
data_Spb = data_Spb.groupby('distance_to_center')['price_per_sqm'].median()
data_Spb.tail(20)
data_Spb.plot(x='distance_to_center', y='price_per_sqm', kind='line', title='График зависимости цены кв. м от расстояния до центра')
plt.xlabel('distance_to_center')
plt.ylabel('price_per_sqm')
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Отличная визуализация.

# %% [markdown]
# Вывод - дальше от центра стоимость падает. Наблюдаемые скачки - скорее всего локальные области с высокой популярностью - наличие парков, крупных культурных и торговых центров.

# %% [markdown]
# ### 5. Общие выводы
#
# Проведён общий анализ предоставленных данных. Заполнены отсутствующие данные, исправлены проблемы с названиями населённых пунктов. По анализу полученных данных можно сделать выводы:
# - Наиболее часты объявления 1-3-х комнатных квартир;
# - средний срок продаж по объявлениям - 2,5 месяца;
# - на стоимость сильнее всего влияет площадь квартиры, зависимость линейная;
# - в крупных городах стоимость падает по мере удаления от центра, но необходимо учитывать локальные популярные места;
# - стоит проявлять осторожность в случае 12-ти комнатных квартир.
# - обнаружился странный провал по объявлениям по квартирам с жилой площадью примерно 25 м<sup>2</sup>

# %% [markdown]
# <div class='alert alert-info'>других изменений кроме 25 метровых квартир не заметил, коэффициенты корреляции не изменились.</div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Шикарный вывод и рекомендации для бизнеса. Кстати, хорошей практикой является написание в общем выводе всех твоих действий (кратко) по проекту. Ведь вывод раскрывает для заказчика всю твою проделанную работу и за что он платит деньги, даже если ему не интересен весь процесс исследования, то в отчёт он заглянет обязательно. Ты молодец!
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
# Комментарий от ревьюера №1 </b>
#
#
#
# У тебя получилась очень сильная и хорошая работа. Здорово, что расчеты ты сопровождаешь иллюстрациями, а так же не забываешь про комментарии, твой проект интересно проверять.
#
# ---
#
# Нужно поправить:
#
# 1) Вводная часть
#
# 2) Замена пропусков
#
# 3) Типы данных
#
# 4) Проверка на дубликаты
#
# 5) Шаг 4.1 (поправить графики)
#
# 6) Аномалии
#
# 7) Какие продажи можно считать быстрыми, а какие — необычно долгими?
#
# 8) Шаг 4.3 (графики + корреляция Пирсона для площадей)
#
# 9) После каждого раздела / графика (или серии тестов) писать вывод по полученным данным с учетом поставленной бизнес задачи
#
# 10) Подправить выводы, после изменений
#
# ----
#
#
# Если у тебя будут какие-то вопросы по моим комментариям - обязательно пиши! Буду ждать работу на повторное ревью :)</div>

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
# Комментарий от ревьюера №2 </b>
#
#
#
# Отличная работа. Осталось поправить пару моментов:
#
# ---
#
# Нужно поправить:
#
# 1) Вводная часть
#
# 2) Замена пропусков
#
# 3) Аномалии
#
# 4) Шаг 4.3 (день/месяц/год)
#
# 5) Подправить выводы, после изменений
#
# ----
#
#
# Если у тебя будут какие-то вопросы по моим комментариям - обязательно пиши! Буду ждать работу на повторное ревью :)</div>

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
# Комментарий от ревьюера №3 </b>
#
#
#
# Последний штрих:
#
# ---
#
# Нужно поправить:
#
# 1) Замена пропусков
#
# 2) Подправить выводы, после изменений
#
# ----
#
#
# Если у тебя будут какие-то вопросы по моим комментариям - обязательно пиши! Буду ждать работу на повторное ревью :)</div>

# %% [markdown]
# <div style="border:solid blue 3px; padding: 20px">
# <div class="alert alert-block alert-success">✔️
#
#
# __Коментарий от ревьюера №4__
#
#
# В остальном всё чудно😊. Твой проект так и просится на github =)
#
# Поздравляю с успешным завершением проекта 😊👍
# И желаю успехов в новых работах 😊
#
# ---
#
# От себя хочу порекомендовать тебе отличную книгу про язык Python. Она очень классная (можно купить как новую, так и на Авито попадается. Вот ссылка на pdf этой книги)
#
# https://monster-book.com/avtomatizaciya-zadach-s-python
# </div>
